# %%
import soditools.soditools as u
import pandas as pd
import numpy as np

# %%
country_id = 'PE'

plp_file = f'UPSELL_{country_id}.csv'
plp_bucket = f'bucket_recommender_{country_id.lower()}'
plp_path = f'gs://{plp_bucket}/'

sandbox_file = f'UPSELL_{country_id}.csv'
sandbox_bucket = f'bucket_recommender_sandbox_{country_id.lower()}'
sandbox_path = f'gs://{sandbox_bucket}/'

# %%
# df = pd.read_csv(_path+_file)
df_plp = pd.read_csv(plp_path+plp_file)

# %%
df_plp.head()
# Out:
#   productId                                       upsell_a_pro  \
# 0   3827992  356727|4151755|1679937|4151763|4151747|4276841...
# 1   3546543  1160486|4364430|4358651|4358694|1016911|436224...
# 2   4239040  4301064|4238842|4301072|430134X|4300416|404629...
# 3   272359X  268666|8974713|8974705|269751|321028|268631|26...
# 4   2667789  8845948|8845433|8845956|8967652|8966567|902205...
#
#                                       upsell_a_hogar  \
# 0  356727|4151755|1679937|4151763|4151747|4276841...
# 1  1160486|4364430|4358651|4358694|1016911|436224...
# 2  4301064|4238842|4301072|430134X|4300416|404629...
# 3  268666|8974713|8974705|269751|321028|268631|26...
# 4  8845948|8845433|8845956|8967652|8966567|902205...
#
#                                upsell_a_sin_segmento  \
# 0  356727|4151755|1679937|4151763|4151747|4276841...
# 1  1160486|4364430|4358651|4358694|1016911|436224...
# 2  4301064|4238842|4301072|430134X|4300416|404629...
# 3  268666|8974713|8974705|269751|321028|268631|26...
# 4  8845948|8845433|8845956|8967652|8966567|902205...
#
#                                         upsell_b_pro  \
# 0  356727|4151755|1679937|4151763|4151747|4276841...
# 1  1160486|4364430|4358651|4358694|1016911|436224...
# 2  4239059|4238842|4238834|8754276|4064313|881828...
# 3  268666|8974713|8974705|269751|321028|268631|26...
# 4  8845948|8845433|8845956|8967652|8966567|902205...
#
#                                       upsell_b_hogar  \
# 0  356727|4151755|1679937|4151763|4151747|4276841...
# 1  1160486|4364430|4358651|4358694|1016911|436224...
# 2  4239059|4238842|4238834|4064313|9051929|406418...
# 3  268666|8974713|8974705|269751|321028|268631|26...
# 4  8845948|8845433|8845956|8967652|8966567|902205...
#
#                                upsell_b_sin_segmento
# 0  356727|4151755|1679937|4151763|4151747|4276841...
# 1  1160486|4364430|4358651|4358694|1016911|436224...
# 2  4239059|4238842|4238834|8755280|2278758|899761...
# 3  268666|8974713|8974705|269751|321028|268631|26...
# 4  8845948|8845433|8845956|8967652|8966567|902205...

# %%
df_sandbox = pd.read_csv(sandbox_path+sandbox_file)

# %%
df_sandbox.head()
# Out:
#   productId                                       upsell_a_pro  \
# 0   3352641  2585782|258591X|2599252|2585979|259921X|258596...
# 1   3341348  883704X|2571579|2571560|2571609|8837031|883705...
# 2   3448274  9017186|2942275|2942267|1118439|132543|1389203...
# 3   2249421  2339072|1380397|2762978|1049992|1854739|136542...
# 4    269670  269751|8974713|4094131|268666|26962X|4126793|4...
#
#                                       upsell_a_hogar  \
# 0  2585782|258591X|2599252|2585979|259921X|258596...
# 1  883704X|2571579|2571560|2571609|8837031|883705...
# 2  9017186|2942275|2942267|1118439|132543|1389203...
# 3  2339072|1380397|2762978|1049992|1854739|136542...
# 4  269751|8974713|4094131|268666|26962X|4126793|4...
#
#                                upsell_a_sin_segmento  \
# 0  2585782|258591X|2599252|2585979|259921X|258596...
# 1  883704X|2571579|2571560|2571609|8837031|883705...
# 2  9017186|2942275|2942267|1118439|132543|1389203...
# 3  2339072|1380397|2762978|1049992|1854739|136542...
# 4  269751|8974713|4094131|268666|26962X|4126793|4...
#
#                                         upsell_b_pro  \
# 0  2585782|258591X|2599252|2585979|259921X|258596...
# 1  883704X|2571579|2571560|2571609|8837031|883705...
# 2  9017186|9011714|2034905|2942313|2937239|294227...
# 3  2339072|1380397|2762978|1049992|1854739|136542...
# 4  26962X|3490432|269751|199526X|4094131|202182X|...
#
#                                       upsell_b_hogar  \
# 0  2585782|258591X|2599252|2585979|259921X|258596...
# 1  883704X|2571579|2571560|2571609|8837031|883705...
# 2  9017186|2034905|9011714|2942313|132594|2942275...
# 3  2339072|1380397|2762978|1049992|1854739|136542...
# 4  26962X|3490432|202182X|4094409|269751|199526X|...
#
#                                upsell_b_sin_segmento
# 0  2585782|258591X|2599252|2585979|259921X|258596...
# 1  883704X|2571579|2571560|2571609|8837031|883705...
# 2  9017186|2034905|9011714|2942313|2942275|293723...
# 3  2339072|1380397|2762978|1049992|1854739|136542...
# 4  26962X|3490432|199526X|269751|4094409|268631|4...

# %%
df_plp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111746 entries, 0 to 111745
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   productId              111746 non-null  object
#  1   upsell_a_pro           106304 non-null  object
#  2   upsell_a_hogar         106304 non-null  object
#  3   upsell_a_sin_segmento  106304 non-null  object
#  4   upsell_b_pro           111746 non-null  object
#  5   upsell_b_hogar         111746 non-null  object
#  6   upsell_b_sin_segmento  111746 non-null  object
# dtypes: object(7)
# memory usage: 6.0+ MB

# %%
df_sandbox.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111744 entries, 0 to 111743
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   productId              111744 non-null  object
#  1   upsell_a_pro           106301 non-null  object
#  2   upsell_a_hogar         106301 non-null  object
#  3   upsell_a_sin_segmento  106301 non-null  object
#  4   upsell_b_pro           111744 non-null  object
#  5   upsell_b_hogar         111744 non-null  object
#  6   upsell_b_sin_segmento  111744 non-null  object
# dtypes: object(7)
# memory usage: 6.0+ MB

# %%
_cols = ['productId','upsell_b_sin_segmento','upsell_b_pro','upsell_b_hogar']
df = pd.merge(left=df_plp[_cols], right=df_sandbox[_cols], how='outer', on='productId', suffixes=['_plp','_sandbox'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111748 entries, 0 to 111747
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   productId                      111748 non-null  object
#  1   upsell_b_sin_segmento_plp      111746 non-null  object
#  2   upsell_b_pro_plp               111746 non-null  object
#  3   upsell_b_hogar_plp             111746 non-null  object
#  4   upsell_b_sin_segmento_sandbox  111744 non-null  object
#  5   upsell_b_pro_sandbox           111744 non-null  object
#  6   upsell_b_hogar_sandbox         111744 non-null  object
# dtypes: object(7)
# memory usage: 6.0+ MB

# %%
df.head()
# Out:
#   productId                          upsell_b_sin_segmento_plp  \
# 0   3827992  356727|4151755|1679937|4151763|4151747|4276841...
# 1   3546543  1160486|4364430|4358651|4358694|1016911|436224...
# 2   4239040  4239059|4238842|4238834|8755280|2278758|899761...
# 3   272359X  268666|8974713|8974705|269751|321028|268631|26...
# 4   2667789  8845948|8845433|8845956|8967652|8966567|902205...
#
#                                     upsell_b_pro_plp  \
# 0  356727|4151755|1679937|4151763|4151747|4276841...
# 1  1160486|4364430|4358651|4358694|1016911|436224...
# 2  4239059|4238842|4238834|8754276|4064313|881828...
# 3  268666|8974713|8974705|269751|321028|268631|26...
# 4  8845948|8845433|8845956|8967652|8966567|902205...
#
#                                   upsell_b_hogar_plp  \
# 0  356727|4151755|1679937|4151763|4151747|4276841...
# 1  1160486|4364430|4358651|4358694|1016911|436224...
# 2  4239059|4238842|4238834|4064313|9051929|406418...
# 3  268666|8974713|8974705|269751|321028|268631|26...
# 4  8845948|8845433|8845956|8967652|8966567|902205...
#
#                        upsell_b_sin_segmento_sandbox  \
# 0  356727|4151763|1679937|4151747|4151755|3744353...
# 1  436225X|4362233|4362241|4364430|4358686|215267...
# 2  4239059|4238842|4238834|8755280|2278758|899761...
# 3  268666|8974713|8974705|269751|268631|26962X|26...
# 4  8845433|9022058|8967571|8845956|902302X|896765...
#
#                                 upsell_b_pro_sandbox  \
# 0  356727|4151763|1679937|4151747|4151755|3744353...
# 1  436225X|4362233|4362241|4364430|4358686|215267...
# 2  4239059|4238842|4238834|8754276|4064313|881828...
# 3  268666|8974713|8974705|269751|268631|26962X|26...
# 4  8845433|9022058|8967571|8845956|902302X|896765...
#
#                               upsell_b_hogar_sandbox
# 0  356727|4151763|1679937|4151747|4151755|3744353...
# 1  436225X|4362233|4362241|4364430|4358686|215267...
# 2  4239059|4238842|4238834|4064313|9051929|406418...
# 3  268666|8974713|8974705|269751|268631|26962X|26...
# 4  8845433|9022058|8967571|8845956|902302X|896765...

# %%
df.describe()
# Out:
#        productId                          upsell_b_sin_segmento_plp  \
# count     111748                                             111746
# unique    111748                                             107564
# top      3827992  1047477|1056492|1713299|1047507|491101|104754X...
# freq           1                                                 30
#
#                                          upsell_b_pro_plp  \
# count                                              111746
# unique                                             107564
# top     1047477|1056492|1713299|1047507|491101|104754X...
# freq                                                   30
#
#                                        upsell_b_hogar_plp  \
# count                                              111746
# unique                                             107564
# top     1047477|1056492|1713299|1047507|491101|104754X...
# freq                                                   30
#
#                             upsell_b_sin_segmento_sandbox  \
# count                                              111744
# unique                                             109589
# top     9051716|1056492|2467402|1047507|1713299|104754...
# freq                                                   83
#
#                                      upsell_b_pro_sandbox  \
# count                                              111744
# unique                                             109589
# top     9051716|1056492|2467402|1047507|1713299|104754...
# freq                                                   83
#
#                                    upsell_b_hogar_sandbox
# count                                              111744
# unique                                             109589
# top     9051716|1056492|2467402|1047507|1713299|104754...
# freq                                                   83

# %%
from typing import Tuple

def compare_lists(str_list1: str, str_list2: str, separator: str = "|") -> Tuple[float, float, float]:
    """
    Compara dos listas representadas como strings usando múltiples métricas:
    - Jaccard Similarity
    - Sorensen-Dice Coefficient
    - Overlap Coefficient
    
    :param str_list1: Primer string de elementos separados por el delimitador.
    :param str_list2: Segundo string de elementos separados por el delimitador.
    :param separator: Caracter que separa los elementos en los strings (por defecto "|").
    :return: (Jaccard, Dice, Overlap)
    """
    if not isinstance(str_list1, str):
        str_list1 = str(str_list1) if str_list1 is not None else ""

    if not isinstance(str_list2, str):
        str_list2 = str(str_list2) if str_list2 is not None else ""

    if not str_list1 or not str_list2:
        return (0.0, 0.0, 0.0)

    set1 = set(str_list1.split(separator))
    set2 = set(str_list2.split(separator))

    intersection = len(set1 & set2)
    union = len(set1 | set2)
    min_size = min(len(set1), len(set2))

    jaccard = intersection / union if union != 0 else 0.0
    dice = (2 * intersection) / (len(set1) + len(set2)) if (len(set1) + len(set2)) != 0 else 0.0
    overlap = intersection / min_size if min_size != 0 else 0.0

    return (jaccard, dice, overlap)

# %%
df.columns
# Out:
# Index(['productId', 'upsell_b_sin_segmento_plp', 'upsell_b_pro_plp',
#        'upsell_b_hogar_plp', 'upsell_b_sin_segmento_sandbox',
#        'upsell_b_pro_sandbox', 'upsell_b_hogar_sandbox'],
#       dtype='object')

# %%
df['sim_b_sin_segmento'] = df[['upsell_b_sin_segmento_plp','upsell_b_sin_segmento_sandbox']].apply(lambda x: compare_lists(x[0],x[1])[1], axis=1)
df['sim_b_pro'] = df[['upsell_b_pro_plp','upsell_b_pro_sandbox']].apply(lambda x: compare_lists(x[0],x[1])[1], axis=1)
df['sim_b_hogar'] = df[['upsell_b_hogar_plp','upsell_b_hogar_sandbox']].apply(lambda x: compare_lists(x[0],x[1])[1], axis=1)

# %%
df.head(10)
# Out:
#   productId                          upsell_b_sin_segmento_plp  \
# 0   3827992  356727|4151755|1679937|4151763|4151747|4276841...
# 1   3546543  1160486|4364430|4358651|4358694|1016911|436224...
# 2   4239040  4239059|4238842|4238834|8755280|2278758|899761...
# 3   272359X  268666|8974713|8974705|269751|321028|268631|26...
# 4   2667789  8845948|8845433|8845956|8967652|8966567|902205...
# 5   2918129  9027092|8967555|8967636|8967547|9022791|896631...
# 6   2667231  9027092|8967636|8967555|8967547|8966311|902442...
# 7   9025987  9023232|9023216|8970068|8748187|9025316|902108...
# 8   3517284  2579995|8713782|8829640|3517888|3517721|882888...
# 9   8737045  8953120|8713367|8953376|8829500|8829462|882949...
#
#                                     upsell_b_pro_plp  \
# 0  356727|4151755|1679937|4151763|4151747|4276841...
# 1  1160486|4364430|4358651|4358694|1016911|436224...
# 2  4239059|4238842|4238834|8754276|4064313|881828...
# 3  268666|8974713|8974705|269751|321028|268631|26...
# 4  8845948|8845433|8845956|8967652|8966567|902205...
# 5  9027092|8967555|8967636|8967547|9022791|896631...
# 6  9027092|8967636|8967555|8967547|8966311|902442...
# 7  9023232|9023216|8970068|8748187|9021485|902324...
# 8  2579995|8713782|8829640|3517888|3517721|882888...
# 9  8953120|8713367|8953333|883010X|8829217|882946...
#
#                                   upsell_b_hogar_plp  \
# 0  356727|4151755|1679937|4151763|4151747|4276841...
# 1  1160486|4364430|4358651|4358694|1016911|436224...
# 2  4239059|4238842|4238834|4064313|9051929|406418...
# 3  268666|8974713|8974705|269751|321028|268631|26...
# 4  8845948|8845433|8845956|8967652|8966567|902205...
# 5  9027092|8967555|8967636|8967547|9022791|896631...
# 6  9027092|8967636|8967555|8967547|8966311|902442...
# 7  9023232|9023216|8970068|8748187|9021485|902247...
# 8  2579995|8713782|8829640|3517888|3517721|882888...
# 9  8953376|8953120|8713367|883010X|9035591|871430...
#
#                        upsell_b_sin_segmento_sandbox  \
# 0  356727|4151763|1679937|4151747|4151755|3744353...
# 1  436225X|4362233|4362241|4364430|4358686|215267...
# 2  4239059|4238842|4238834|8755280|2278758|899761...
# 3  268666|8974713|8974705|269751|268631|26962X|26...
# 4  8845433|9022058|8967571|8845956|902302X|896765...
# 5  9027092|9022791|902302X|8967571|8967563|896763...
# 6  9027092|8967571|9022791|8967601|8967636|902302...
# 7  9023232|9023216|8970068|8748187|9025316|902108...
# 8  2579995|8713782|8829640|3517888|3517721|882888...
# 9  8953120|8713367|8953376|8829500|8829462|882949...
#
#                                 upsell_b_pro_sandbox  \
# 0  356727|4151763|1679937|4151747|4151755|3744353...
# 1  436225X|4362233|4362241|4364430|4358686|215267...
# 2  4239059|4238842|4238834|8754276|4064313|881828...
# 3  268666|8974713|8974705|269751|268631|26962X|26...
# 4  8845433|9022058|8967571|8845956|902302X|896765...
# 5  9027092|9022791|902302X|8967571|8967563|896763...
# 6  9027092|8967571|9022791|8967601|8967636|902302...
# 7  9023232|9023216|8970068|8748187|9021485|902324...
# 8  2579995|8713782|8829640|3517888|3517721|882888...
# 9  8953120|8713367|8953333|883010X|8829217|882946...
#
#                               upsell_b_hogar_sandbox  sim_b_sin_segmento  \
# 0  356727|4151763|1679937|4151747|4151755|3744353...                0.75
# 1  436225X|4362233|4362241|4364430|4358686|215267...                0.80
# 2  4239059|4238842|4238834|4064313|9051929|406418...                1.00
# 3  268666|8974713|8974705|269751|268631|26962X|26...                0.90
# 4  8845433|9022058|8967571|8845956|902302X|896765...                0.55
# 5  9027092|9022791|902302X|8967571|8967563|896763...                0.90
# 6  9027092|8967571|9022791|8967601|8967636|902302...                0.90
# 7  9023232|9023216|8970068|8748187|9021485|902247...                1.00
# 8  2579995|8713782|8829640|3517888|3517721|882888...                0.90
# 9  8953376|8953120|8713367|883010X|9035591|871430...                1.00
#
#    sim_b_pro  sim_b_hogar
# 0       0.75         0.75
# 1       0.80         0.80
# 2       1.00         1.00
# 3       0.90         0.90
# 4       0.55         0.55
# 5       0.90         0.90
# 6       0.90         0.90
# 7       1.00         1.00
# 8       0.90         0.90
# 9       1.00         1.00

# %%
df[['sim_b_sin_segmento','sim_b_pro','sim_b_hogar']].describe()
# Out:
#        sim_b_sin_segmento      sim_b_pro    sim_b_hogar
# count       111748.000000  111748.000000  111748.000000
# mean             0.775766       0.775609       0.775495
# std              0.267904       0.267762       0.267620
# min              0.000000       0.000000       0.000000
# 25%              0.650000       0.650000       0.650000
# 50%              0.900000       0.900000       0.900000
# 75%              1.000000       1.000000       1.000000
# max              1.000000       1.000000       1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

fig, ax = plt.subplots(3,1,figsize=(5,5), sharex=True)
ax = ax.flat

sns.kdeplot(df['sim_b_sin_segmento'], fill=True, ax=ax[0])
ax[0].set_title('Sin Segmento')
ax[0].set_xlabel(None)
sns.kdeplot(df['sim_b_pro'], fill=True, ax=ax[1])
ax[1].set_title('Pro')
ax[1].set_xlabel(None)
sns.kdeplot(df['sim_b_hogar'], fill=True, ax=ax[2])
ax[2].set_title('Hogar')
ax[2].set_xlabel(None)


plt.tight_layout()

# %%
_threshold = .8
np.divide(df[df['sim_b_sin_segmento'] >= _threshold].shape[0], df.shape[0])
# Out:
# 0.6206375058166589
